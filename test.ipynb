# %%
import numpy as np
import matplotlib.pyplot as plt
from processing import processing
import cv2

image_cv2 = cv2.imread('data\IM002025.PNG')
image_cv2 = image_cv2.cvtColor(image_cv2, cv2.COLOR_BGR2RGB)
# st.image(image_cv2)
output_image = processing(image_cv2)
# Out:
# (2094, 2124, 3)

# %%
image_cv2 = cv2.imread('data\IM002025.PNG')
image_cv2 = cv2.cvtColor(image_cv2, cv2.COLOR_BGR2RGB)

# %%
blue = np.zeros(image_cv2.shape)
for i in range(0, len(output_image)):
    for j in range(0, len(output_image[0])):
        if output_image[i][j] != 0:
            image_cv2 = cv2.circle(image_cv2, (i, j), 5, (0,255,0), 1)
# plt.imshow(output_image)
# plt.imshow(blue)
# blue.shape
# alpha = 0
# output_image_superimposed = np.uint8(1*image_cv2 + (1-alpha)*blue)
plt.imshow(image_cv2)
# image_cv2
