# %%
from model import build_UNet

Img_Width = 48
Img_Height = 48
Img_Channels = 1

model = build_UNet((Img_Width, Img_Height, Img_Channels),(Img_Width, Img_Height, Img_Channels))
# Out:
# WARNING:tensorflow:From c:\Users\ayush\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From c:\Users\ayush\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\ayush\AppData\Local\Programs\Python\Python311\Lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.

# %%
model.summary()
# Out:
# Model: "UNet"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 1)]          0         []
#
#  lambda (Lambda)             (None, 48, 48, 1)            0         ['input_1[0][0]']
#
#  conv2d (Conv2D)             (None, 48, 48, 32)           320       ['lambda[0][0]']
#
#  batch_normalization (Batch  (None, 48, 48, 32)           128       ['conv2d[0][0]']
#  Normalization)
#
#  activation (Activation)     (None, 48, 48, 32)           0         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 48, 48, 32)           9248      ['activation[0][0]']
#
#  batch_normalization_1 (Bat  (None, 48, 48, 32)           128       ['conv2d_1[0][0]']
#  chNormalization)
#
#  activation_1 (Activation)   (None, 48, 48, 32)           0         ['batch_normalization_1[0][0]'
#                                                                     ]
#
#  max_pooling2d (MaxPooling2  (None, 24, 24, 32)           0         ['activation_1[0][0]']
#  D)
#
#  dropout (Dropout)           (None, 24, 24, 32)           0         ['max_pooling2d[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 24, 24, 64)           18496     ['dropout[0][0]']
#
#  batch_normalization_2 (Bat  (None, 24, 24, 64)           256       ['conv2d_2[0][0]']
#  chNormalization)
#
#  activation_2 (Activation)   (None, 24, 24, 64)           0         ['batch_normalization_2[0][0]'
#                                                                     ]
#
#  conv2d_3 (Conv2D)           (None, 24, 24, 64)           36928     ['activation_2[0][0]']
#
#  batch_normalization_3 (Bat  (None, 24, 24, 64)           256       ['conv2d_3[0][0]']
#  chNormalization)
#
#  activation_3 (Activation)   (None, 24, 24, 64)           0         ['batch_normalization_3[0][0]'
#                                                                     ]
#
#  max_pooling2d_1 (MaxPoolin  (None, 12, 12, 64)           0         ['activation_3[0][0]']
#  g2D)
#
#  dropout_1 (Dropout)         (None, 12, 12, 64)           0         ['max_pooling2d_1[0][0]']
#
#  conv2d_4 (Conv2D)           (None, 12, 12, 128)          73856     ['dropout_1[0][0]']
#
#  batch_normalization_4 (Bat  (None, 12, 12, 128)          512       ['conv2d_4[0][0]']
#  chNormalization)
#
#  activation_4 (Activation)   (None, 12, 12, 128)          0         ['batch_normalization_4[0][0]'
#                                                                     ]
#
#  conv2d_5 (Conv2D)           (None, 12, 12, 128)          147584    ['activation_4[0][0]']
#
#  batch_normalization_5 (Bat  (None, 12, 12, 128)          512       ['conv2d_5[0][0]']
#  chNormalization)
#
#  activation_5 (Activation)   (None, 12, 12, 128)          0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  max_pooling2d_2 (MaxPoolin  (None, 6, 6, 128)            0         ['activation_5[0][0]']
#  g2D)
#
#  dropout_2 (Dropout)         (None, 6, 6, 128)            0         ['max_pooling2d_2[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 6, 6, 256)            295168    ['dropout_2[0][0]']
#
#  batch_normalization_6 (Bat  (None, 6, 6, 256)            1024      ['conv2d_6[0][0]']
#  chNormalization)
#
#  activation_6 (Activation)   (None, 6, 6, 256)            0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  conv2d_7 (Conv2D)           (None, 6, 6, 256)            590080    ['activation_6[0][0]']
#
#  batch_normalization_7 (Bat  (None, 6, 6, 256)            1024      ['conv2d_7[0][0]']
#  chNormalization)
#
#  activation_7 (Activation)   (None, 6, 6, 256)            0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  max_pooling2d_3 (MaxPoolin  (None, 3, 3, 256)            0         ['activation_7[0][0]']
#  g2D)
#
#  dropout_3 (Dropout)         (None, 3, 3, 256)            0         ['max_pooling2d_3[0][0]']
#
#  conv2d_8 (Conv2D)           (None, 3, 3, 512)            1180160   ['dropout_3[0][0]']
#
#  batch_normalization_8 (Bat  (None, 3, 3, 512)            2048      ['conv2d_8[0][0]']
#  chNormalization)
#
#  activation_8 (Activation)   (None, 3, 3, 512)            0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  conv2d_9 (Conv2D)           (None, 3, 3, 512)            2359808   ['activation_8[0][0]']
#
#  batch_normalization_9 (Bat  (None, 3, 3, 512)            2048      ['conv2d_9[0][0]']
#  chNormalization)
#
#  activation_9 (Activation)   (None, 3, 3, 512)            0         ['batch_normalization_9[0][0]'
#                                                                     ]
#
#  conv2d_transpose (Conv2DTr  (None, 6, 6, 256)            524544    ['activation_9[0][0]']
#  anspose)
#
#  tf.math.reduce_mean (TFOpL  (None, 1, 1, 256)            0         ['conv2d_transpose[0][0]']
#  ambda)
#
#  tf.math.subtract (TFOpLamb  (None, 6, 6, 256)            0         ['conv2d_transpose[0][0]',
#  da)                                                                 'tf.math.reduce_mean[0][0]']
#
#  tf.math.square (TFOpLambda  (None, 6, 6, 256)            0         ['tf.math.subtract[0][0]']
#  )
#
#  tf.math.reduce_sum (TFOpLa  (None, 1, 1, 256)            0         ['tf.math.square[0][0]']
#  mbda)
#
#  tf.math.truediv (TFOpLambd  (None, 1, 1, 256)            0         ['tf.math.reduce_sum[0][0]']
#  a)
#
#  tf.__operators__.add (TFOp  (None, 1, 1, 256)            0         ['tf.math.truediv[0][0]']
#  Lambda)
#
#  tf.math.multiply (TFOpLamb  (None, 1, 1, 256)            0         ['tf.__operators__.add[0][0]']
#  da)
#
#  tf.math.truediv_1 (TFOpLam  (None, 6, 6, 256)            0         ['tf.math.square[0][0]',
#  bda)                                                                'tf.math.multiply[0][0]']
#
#  tf.__operators__.add_1 (TF  (None, 6, 6, 256)            0         ['tf.math.truediv_1[0][0]']
#  OpLambda)
#
#  activation_10 (Activation)  (None, 6, 6, 256)            0         ['tf.__operators__.add_1[0][0]
#                                                                     ']
#
#  multiply (Multiply)         (None, 6, 6, 256)            0         ['activation_7[0][0]',
#                                                                      'activation_10[0][0]']
#
#  concatenate (Concatenate)   (None, 6, 6, 512)            0         ['conv2d_transpose[0][0]',
#                                                                      'multiply[0][0]']
#
#  dropout_4 (Dropout)         (None, 6, 6, 512)            0         ['concatenate[0][0]']
#
#  conv2d_10 (Conv2D)          (None, 6, 6, 256)            1179904   ['dropout_4[0][0]']
#
#  batch_normalization_10 (Ba  (None, 6, 6, 256)            1024      ['conv2d_10[0][0]']
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 6, 6, 256)            0         ['batch_normalization_10[0][0]
#                                                                     ']
#
#  conv2d_transpose_1 (Conv2D  (None, 12, 12, 128)          131200    ['activation_11[0][0]']
#  Transpose)
#
#  tf.math.reduce_mean_1 (TFO  (None, 1, 1, 128)            0         ['conv2d_transpose_1[0][0]']
#  pLambda)
#
#  tf.math.subtract_1 (TFOpLa  (None, 12, 12, 128)          0         ['conv2d_transpose_1[0][0]',
#  mbda)                                                               'tf.math.reduce_mean_1[0][0]'
#                                                                     ]
#
#  tf.math.square_1 (TFOpLamb  (None, 12, 12, 128)          0         ['tf.math.subtract_1[0][0]']
#  da)
#
#  tf.math.reduce_sum_1 (TFOp  (None, 1, 1, 128)            0         ['tf.math.square_1[0][0]']
#  Lambda)
#
#  tf.math.truediv_2 (TFOpLam  (None, 1, 1, 128)            0         ['tf.math.reduce_sum_1[0][0]']
#  bda)
#
#  tf.__operators__.add_2 (TF  (None, 1, 1, 128)            0         ['tf.math.truediv_2[0][0]']
#  OpLambda)
#
#  tf.math.multiply_1 (TFOpLa  (None, 1, 1, 128)            0         ['tf.__operators__.add_2[0][0]
#  mbda)                                                              ']
#
#  tf.math.truediv_3 (TFOpLam  (None, 12, 12, 128)          0         ['tf.math.square_1[0][0]',
#  bda)                                                                'tf.math.multiply_1[0][0]']
#
#  tf.__operators__.add_3 (TF  (None, 12, 12, 128)          0         ['tf.math.truediv_3[0][0]']
#  OpLambda)
#
#  activation_12 (Activation)  (None, 12, 12, 128)          0         ['tf.__operators__.add_3[0][0]
#                                                                     ']
#
#  multiply_1 (Multiply)       (None, 12, 12, 128)          0         ['activation_5[0][0]',
#                                                                      'activation_12[0][0]']
#
#  concatenate_1 (Concatenate  (None, 12, 12, 256)          0         ['conv2d_transpose_1[0][0]',
#  )                                                                   'multiply_1[0][0]']
#
#  dropout_5 (Dropout)         (None, 12, 12, 256)          0         ['concatenate_1[0][0]']
#
#  conv2d_11 (Conv2D)          (None, 12, 12, 128)          295040    ['dropout_5[0][0]']
#
#  batch_normalization_11 (Ba  (None, 12, 12, 128)          512       ['conv2d_11[0][0]']
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 12, 12, 128)          0         ['batch_normalization_11[0][0]
#                                                                     ']
#
#  conv2d_transpose_2 (Conv2D  (None, 24, 24, 64)           32832     ['activation_13[0][0]']
#  Transpose)
#
#  tf.math.reduce_mean_2 (TFO  (None, 1, 1, 64)             0         ['conv2d_transpose_2[0][0]']
#  pLambda)
#
#  tf.math.subtract_2 (TFOpLa  (None, 24, 24, 64)           0         ['conv2d_transpose_2[0][0]',
#  mbda)                                                               'tf.math.reduce_mean_2[0][0]'
#                                                                     ]
#
#  tf.math.square_2 (TFOpLamb  (None, 24, 24, 64)           0         ['tf.math.subtract_2[0][0]']
#  da)
#
#  tf.math.reduce_sum_2 (TFOp  (None, 1, 1, 64)             0         ['tf.math.square_2[0][0]']
#  Lambda)
#
#  tf.math.truediv_4 (TFOpLam  (None, 1, 1, 64)             0         ['tf.math.reduce_sum_2[0][0]']
#  bda)
#
#  tf.__operators__.add_4 (TF  (None, 1, 1, 64)             0         ['tf.math.truediv_4[0][0]']
#  OpLambda)
#
#  tf.math.multiply_2 (TFOpLa  (None, 1, 1, 64)             0         ['tf.__operators__.add_4[0][0]
#  mbda)                                                              ']
#
#  tf.math.truediv_5 (TFOpLam  (None, 24, 24, 64)           0         ['tf.math.square_2[0][0]',
#  bda)                                                                'tf.math.multiply_2[0][0]']
#
#  tf.__operators__.add_5 (TF  (None, 24, 24, 64)           0         ['tf.math.truediv_5[0][0]']
#  OpLambda)
#
#  activation_14 (Activation)  (None, 24, 24, 64)           0         ['tf.__operators__.add_5[0][0]
#                                                                     ']
#
#  multiply_2 (Multiply)       (None, 24, 24, 64)           0         ['activation_3[0][0]',
#                                                                      'activation_14[0][0]']
#
#  concatenate_2 (Concatenate  (None, 24, 24, 128)          0         ['conv2d_transpose_2[0][0]',
#  )                                                                   'multiply_2[0][0]']
#
#  dropout_6 (Dropout)         (None, 24, 24, 128)          0         ['concatenate_2[0][0]']
#
#  conv2d_12 (Conv2D)          (None, 24, 24, 64)           73792     ['dropout_6[0][0]']
#
#  batch_normalization_12 (Ba  (None, 24, 24, 64)           256       ['conv2d_12[0][0]']
#  tchNormalization)
#
#  activation_15 (Activation)  (None, 24, 24, 64)           0         ['batch_normalization_12[0][0]
#                                                                     ']
#
#  conv2d_transpose_3 (Conv2D  (None, 48, 48, 32)           8224      ['activation_15[0][0]']
#  Transpose)
#
#  tf.math.reduce_mean_3 (TFO  (None, 1, 1, 32)             0         ['conv2d_transpose_3[0][0]']
#  pLambda)
#
#  tf.math.subtract_3 (TFOpLa  (None, 48, 48, 32)           0         ['conv2d_transpose_3[0][0]',
#  mbda)                                                               'tf.math.reduce_mean_3[0][0]'
#                                                                     ]
#
#  tf.math.square_3 (TFOpLamb  (None, 48, 48, 32)           0         ['tf.math.subtract_3[0][0]']
#  da)
#
#  tf.math.reduce_sum_3 (TFOp  (None, 1, 1, 32)             0         ['tf.math.square_3[0][0]']
#  Lambda)
#
#  tf.math.truediv_6 (TFOpLam  (None, 1, 1, 32)             0         ['tf.math.reduce_sum_3[0][0]']
#  bda)
#
#  tf.__operators__.add_6 (TF  (None, 1, 1, 32)             0         ['tf.math.truediv_6[0][0]']
#  OpLambda)
#
#  tf.math.multiply_3 (TFOpLa  (None, 1, 1, 32)             0         ['tf.__operators__.add_6[0][0]
#  mbda)                                                              ']
#
#  tf.math.truediv_7 (TFOpLam  (None, 48, 48, 32)           0         ['tf.math.square_3[0][0]',
#  bda)                                                                'tf.math.multiply_3[0][0]']
#
#  tf.__operators__.add_7 (TF  (None, 48, 48, 32)           0         ['tf.math.truediv_7[0][0]']
#  OpLambda)
#
#  activation_16 (Activation)  (None, 48, 48, 32)           0         ['tf.__operators__.add_7[0][0]
#                                                                     ']
#
#  multiply_3 (Multiply)       (None, 48, 48, 32)           0         ['activation_1[0][0]',
#                                                                      'activation_16[0][0]']
#
#  concatenate_3 (Concatenate  (None, 48, 48, 64)           0         ['conv2d_transpose_3[0][0]',
#  )                                                                   'multiply_3[0][0]']
#
#  dropout_7 (Dropout)         (None, 48, 48, 64)           0         ['concatenate_3[0][0]']
#
#  input_2 (InputLayer)        [(None, 48, 48, 1)]          0         []
#
#  tf.math.square_4 (TFOpLamb  (None, 48, 48, 32)           0         ['activation_16[0][0]']
#  da)
#
#  conv2d_13 (Conv2D)          (None, 48, 48, 32)           18464     ['dropout_7[0][0]']
#
#  tf.math.multiply_4 (TFOpLa  (None, 48, 48, 32)           0         ['input_2[0][0]',
#  mbda)                                                               'tf.math.square_4[0][0]']
#
#  tf.math.reduce_sum_5 (TFOp  (None, 1)                    0         ['input_2[0][0]']
#  Lambda)
#
#  batch_normalization_13 (Ba  (None, 48, 48, 32)           128       ['conv2d_13[0][0]']
#  tchNormalization)
#
#  tf.math.reduce_sum_4 (TFOp  (None, 32)                   0         ['tf.math.multiply_4[0][0]']
#  Lambda)
#
#  tf.__operators__.add_8 (TF  (None, 1)                    0         ['tf.math.reduce_sum_5[0][0]']
#  OpLambda)
#
#  activation_17 (Activation)  (None, 48, 48, 32)           0         ['batch_normalization_13[0][0]
#                                                                     ']
#
#  tf.math.truediv_8 (TFOpLam  (None, 32)                   0         ['tf.math.reduce_sum_4[0][0]',
#  bda)                                                                'tf.__operators__.add_8[0][0]
#                                                                     ']
#
#  conv2d_14 (Conv2D)          (None, 48, 48, 1)            33        ['activation_17[0][0]']
#
#  tf.math.reduce_min (TFOpLa  (None,)                      0         ['tf.math.truediv_8[0][0]']
#  mbda)
#
# ==================================================================================================
# Total params: 6985537 (26.65 MB)
# Trainable params: 6980609 (26.63 MB)
# Non-trainable params: 4928 (19.25 KB)
# __________________________________________________________________________________________________

# %%
model.layers[-4].output
# Out:
# <KerasTensor: shape=(None, 48, 48, 32) dtype=float32 (created by layer 'activation_17')>
